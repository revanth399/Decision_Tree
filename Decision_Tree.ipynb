# %% [markdown]
# <a href="https://colab.research.google.com/github/PARAMKUSAMGOPISAISHANKAR/Decision-Tree-Classification/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/sample_data/iris CSV.txt')  # Corrected quote

# %%
X = data.drop('species', axis=1)  # Corrected quote
Y = data['species']  # Corrected quote

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
Y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy:.4f}")  # Corrected quote
# Out:
# Accuracy: 1.0000

# %%
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed
plot_tree(model, feature_names=X.columns, class_names=model.classes_, filled=True, rounded=True)
plt.show()  # Corrected plot.show()
